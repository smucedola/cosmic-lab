# %% [markdown]
# # Recap

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Papers are provided in the e-learning covering all of the lectures. Notice that the more we know about galaxies the less we actually know!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# You can see on graph on the left there seems to be inflow other than outflow due to supernovae feedback $\eta$ for massive galaxies. This is an active side of research, for example what causes the outflow in massive galaxies, what is $\xi = \zeta$? Maybe AGN feedback but not only.
#
# So what is $\xi$ and how do galaxies get their gas? this is still open field of research

# %% [markdown]
# ## Report
